# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train_data=pd.read_excel('Data_Train.xlsx')
test_data=pd.read_excel('Test_set.xlsx')

# %%
train_data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
train_data.shape
# Out:
# (10683, 11)

# %%
test_data.shape
# Out:
# (2671, 10)

# %%
data=pd.concat([train_data,test_data])

# %%
data.tail()
# Out:
#                 Airline Date_of_Journey   Source Destination            Route  \
# 2666          Air India       6/06/2019  Kolkata    Banglore  CCU → DEL → BLR
# 2667             IndiGo      27/03/2019  Kolkata    Banglore        CCU → BLR
# 2668        Jet Airways       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2669          Air India       6/03/2019    Delhi      Cochin  DEL → BOM → COK
# 2670  Multiple carriers      15/06/2019    Delhi      Cochin  DEL → BOM → COK
#
#      Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 2666    20:30  20:25 07 Jun  23h 55m      1 stop         No info    NaN
# 2667    14:20         16:55   2h 35m    non-stop         No info    NaN
# 2668    21:50  04:25 07 Mar   6h 35m      1 stop         No info    NaN
# 2669    04:00         19:15  15h 15m      1 stop         No info    NaN
# 2670    04:55         19:15  14h 20m      1 stop         No info    NaN

# %%
data.shape
# Out:
# (13354, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13354 entries, 0 to 2670
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
data.describe()
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %% [markdown]
# ##feature engineering for Date of journey

# %%
data['journey_day']=data['Date_of_Journey'].str.split('/').str[0]

# %%
data['journey_month']=data['Date_of_Journey'].str.split('/').str[1]
data['journey_year']=data['Date_of_Journey'].str.split('/').str[2]

# %% [markdown]
# ## still the above columns are in the object type we should want to change it as int

# %%
data['journey_day']=data['journey_day'].astype(int)
data['journey_month']=data['journey_month'].astype(int)
data['journey_year']=data['journey_year'].astype(int)

# %%
data.shape
# Out:
# (13354, 13)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
#
#   Arrival_Time Duration Total_Stops Additional_Info    Price  journey_day  \
# 0        01:10   2h 50m    non-stop         No info   3897.0           24
# 1        13:15   7h 25m     2 stops         No info   7662.0            1
# 2        04:25      19h     2 stops         No info  13882.0            9
# 3        23:30   5h 25m      1 stop         No info   6218.0           12
# 4        21:35   4h 45m      1 stop         No info  13302.0            1
#
#    journey_month  journey_year
# 0              3          2019
# 1              5          2019
# ...

# %%
data.shape
# Out:
# (13354, 13)

# %%
data['Arrival_Time']=data['Arrival_Time'].str.split(' ').str[0] ##taking only [hour and minute]

# %%
data['arival_hour']=data['Arrival_Time'].str.split(':').str[0]
data['arival_minute']=data['Arrival_Time'].str.split(':').str[1]

# %%
data['arival_hour']=data['arival_hour'].astype(int)
data['arival_minute']=data['arival_minute'].astype(int)

# %%
data.drop('Arrival_Time',axis=1,inplace=True)

# %%
data.shape
# Out:
# (13354, 14)

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  journey_day  journey_month  \
# 0    non-stop         No info   3897.0           24              3
# 1     2 stops         No info   7662.0            1              5
# 2     2 stops         No info  13882.0            9              6
# 3      1 stop         No info   6218.0           12              5
# 4      1 stop         No info  13302.0            1              3
#
#    journey_year  arival_hour  arival_minute
# 0          2019            1             10
# ...

# %%
data['dep_hour']=data['Dep_Time'].str.split(':').str[0]
data['dep_minute']=data['Dep_Time'].str.split(':').str[1]

# %%
data['dep_hour']=data['dep_hour'].astype(int)
data['dep_minute']=data['dep_minute'].astype(int)

# %%
data.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Route               object
# Dep_Time            object
# Duration            object
# Total_Stops         object
# Additional_Info     object
# Price              float64
# journey_day          int32
# journey_month        int32
# journey_year         int32
# arival_hour          int32
# arival_minute        int32
# dep_hour             int32
# dep_minute           int32
# dtype: object

# %%
data.head()
# Out:
#        Airline    Source Destination                  Route Dep_Time Duration  \
# 0       IndiGo  Banglore   New Delhi              BLR → DEL    22:20   2h 50m
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50   4h 45m
#
#   Total_Stops Additional_Info    Price  journey_day  journey_month  \
# 0    non-stop         No info   3897.0           24              3
# 1     2 stops         No info   7662.0            1              5
# 2     2 stops         No info  13882.0            9              6
# 3      1 stop         No info   6218.0           12              5
# 4      1 stop         No info  13302.0            1              3
#
#    journey_year  arival_hour  arival_minute  dep_hour  dep_minute
# ...

# %%
data.drop('Dep_Time',axis=1,inplace=True)

# %%
data.shape
# Out:
# (13354, 15)

# %%
data.Total_Stops.unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
data['Total_Stops']=data['Total_Stops'].map({'non-stop':0,'1 stop':1,'2 stop':2,'3 stop':3,'4 stop':4,'nan':4})

# %%
data.Total_Stops.dtype
# Out:
# dtype('float64')

# %%
data.drop('Route',axis=1,inplace=True)

# %%
data.shape
# Out:
# (13354, 14)

# %%
data.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          NaN         No info
# 2  Jet Airways     Delhi      Cochin      19h          NaN         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  journey_day  journey_month  journey_year  arival_hour  \
# 0   3897.0           24              3          2019            1
# 1   7662.0            1              5          2019           13
# 2  13882.0            9              6          2019            4
# 3   6218.0           12              5          2019           23
# 4  13302.0            1              3          2019           21
#
#    arival_minute  dep_hour  dep_minute
# 0             10        22          20
# ...

# %%
data['Duration_hour']=data['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
data['Duration_hour']
# Out:
# 0        2
# 1        7
# 2       19
# 3        5
# 4        4
#         ..
# 2666    23
# 2667     2
# 2668     6
# 2669    15
# 2670    14
# Name: Duration_hour, Length: 13354, dtype: object

# %%
data['Duration_minute']=data['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
data[data['Duration_minute'].isnull()]
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 2           Jet Airways     Delhi      Cochin      19h          NaN
# 18            Air India     Delhi      Cochin      23h          NaN
# 33          Jet Airways     Delhi      Cochin      22h          NaN
# 44    Multiple carriers     Delhi      Cochin      12h          1.0
# 53               IndiGo  Banglore       Delhi       3h          0.0
# ...                 ...       ...         ...      ...          ...
# 2598        Jet Airways     Delhi      Cochin      11h          1.0
# 2604  Multiple carriers     Delhi      Cochin      10h          1.0
# 2607  Multiple carriers     Delhi      Cochin      13h          1.0
# 2622        Jet Airways  Banglore       Delhi       3h          0.0
# 2660          Air India    Mumbai   Hyderabad       5m          NaN
#
#                   Additional_Info    Price  journey_day  journey_month  \
# 2                         No info  13882.0            9              6
# ...

# %%
data
# Out:
#                 Airline    Source Destination Duration  Total_Stops  \
# 0                IndiGo  Banglore   New Delhi   2h 50m          0.0
# 1             Air India   Kolkata    Banglore   7h 25m          NaN
# 2           Jet Airways     Delhi      Cochin      19h          NaN
# 3                IndiGo   Kolkata    Banglore   5h 25m          1.0
# 4                IndiGo  Banglore   New Delhi   4h 45m          1.0
# ...                 ...       ...         ...      ...          ...
# 2666          Air India   Kolkata    Banglore  23h 55m          1.0
# 2667             IndiGo   Kolkata    Banglore   2h 35m          0.0
# 2668        Jet Airways     Delhi      Cochin   6h 35m          1.0
# 2669          Air India     Delhi      Cochin  15h 15m          1.0
# 2670  Multiple carriers     Delhi      Cochin  14h 20m          1.0
#
#      Additional_Info    Price  journey_day  journey_month  journey_year  \
# 0            No info   3897.0           24              3          2019
# ...

# %%
data.dtypes
# Out:
# Airline             object
# Source              object
# Destination         object
# Duration            object
# Total_Stops        float64
# Additional_Info     object
# Price              float64
# journey_day          int32
# journey_month        int32
# journey_year         int32
# arival_hour          int32
# arival_minute        int32
# dep_hour             int32
# dep_minute           int32
# Duration_hour       object
# Duration_minute     object
# dtype: object

# %%
##this making  error
data['Duration_hour']=data['Duration_hour'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 2
#       1 ##this making  error
# ----> 2 data['Duration_hour']=data['Duration_hour'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
# ...

# %%
data[data['Duration_hour']=='5m']
# Out:
#         Airline  Source Destination Duration  Total_Stops Additional_Info  \
# 6474  Air India  Mumbai   Hyderabad       5m          NaN         No info
# 2660  Air India  Mumbai   Hyderabad       5m          NaN         No info
#
#         Price  journey_day  journey_month  journey_year  arival_hour  \
# 6474  17327.0            6              3          2019           16
# 2660      NaN           12              3          2019           16
#
#       arival_minute  dep_hour  dep_minute Duration_hour Duration_minute
# 6474             55        16          50            5m             NaN
# 2660             55        16          50            5m             NaN

# %%
data.drop(6474,axis=0,inplace=True)
data.drop(2660,axis=0,inplace=True)

# %%
data['Duration_hour']=data['Duration_hour'].astype(int)

# %%
data.head()
# Out:
#        Airline    Source Destination Duration  Total_Stops Additional_Info  \
# 0       IndiGo  Banglore   New Delhi   2h 50m          0.0         No info
# 1    Air India   Kolkata    Banglore   7h 25m          NaN         No info
# 2  Jet Airways     Delhi      Cochin      19h          NaN         No info
# 3       IndiGo   Kolkata    Banglore   5h 25m          1.0         No info
# 4       IndiGo  Banglore   New Delhi   4h 45m          1.0         No info
#
#      Price  journey_day  journey_month  journey_year  arival_hour  \
# 0   3897.0           24              3          2019            1
# 1   7662.0            1              5          2019           13
# 2  13882.0            9              6          2019            4
# 3   6218.0           12              5          2019           23
# 4  13302.0            1              3          2019           21
#
#    arival_minute  dep_hour  dep_minute  Duration_hour Duration_minute
# ...

# %%
data.drop('Duration',axis=1,inplace=True)

# %%
data.shape
# Out:
# (13351, 15)

# %%
data.Airline.value_counts()
# Out:
# Airline
# Jet Airways                          4745
# IndiGo                               2564
# Air India                            2190
# Multiple carriers                    1543
# SpiceJet                             1026
# Vistara                               608
# Air Asia                              405
# GoAir                                 240
# Multiple carriers Premium economy      16
# Jet Airways Business                    8
# Vistara Premium economy                 5
# Trujet                                  1
# Name: count, dtype: int64

# %%
filtered_data = data[data['Price'] >= 9000]

filtered_data.shape
# Out:
# (4901, 15)

# %%
from sklearn.preprocessing import LabelEncoder
label=LabelEncoder()

# %%
data['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
data['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
data['Airline']=label.fit_transform(data['Airline'])
data['Source']=label.fit_transform(data['Source'])
data['Destination']=label.fit_transform(data['Destination'])

# %%
data.dtypes
# Out:
# Airline              int64
# Source               int32
# Destination          int32
# Total_Stops        float64
# Additional_Info     object
# Price              float64
# journey_day          int32
# journey_month        int32
# journey_year         int32
# arival_hour          int32
# arival_minute        int32
# dep_hour             int32
# dep_minute           int32
# Duration_hour        int32
# Duration_minute     object
# dtype: object

# %%
data.drop('Duration_minute',axis=1,inplace=True)

# %%
data.shape
# Out:
# (13351, 14)

# %%
data['Additional_Info'].unique()
# Out:
# array(['No info', 'In-flight meal not included',
#        'No check-in baggage included', '1 Short layover', 'No Info',
#        '1 Long layover', 'Change airports', 'Business class',
#        'Red-eye flight', '2 Long layover'], dtype=object)

# %%
len(data['Additional_Info'].unique())
# Out:
# 10

# %%
data['Additional_Info'].isnull().sum()
# Out:
# 0

# %%
data['Additional_Info']=label.fit_transform(data['Additional_Info'])

# %%
data.head()
# Out:
#    Airline  Source  Destination  Total_Stops  Additional_Info    Price  \
# 0        3       0            5          0.0                8   3897.0
# 1        1       3            0          NaN                8   7662.0
# 2        4       2            1          NaN                8  13882.0
# 3        3       3            0          1.0                8   6218.0
# 4        3       0            5          1.0                8  13302.0
#
#    journey_day  journey_month  journey_year  arival_hour  arival_minute  \
# 0           24              3          2019            1             10
# 1            1              5          2019           13             15
# 2            9              6          2019            4             25
# 3           12              5          2019           23             30
# 4            1              3          2019           21             35
#
#    dep_hour  dep_minute  Duration_hour
# 0        22          20              2
# ...

# %%
data.isnull().sum()
# Out:
# Airline               0
# Source                0
# Destination           0
# Total_Stops        1955
# Additional_Info       0
# Price              2670
# journey_day           0
# journey_month         0
# journey_year          0
# arival_hour           0
# arival_minute         0
# dep_hour              0
# dep_minute            0
# Duration_hour         0
# dtype: int64

# %%
data['Total_Stops'].mean()
# Out:
# 0.6191646191646192

# %%
data['Total_Stops'].unique()
# Out:
# array([ 0., nan,  1.])
